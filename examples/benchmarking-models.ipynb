# %%
# !pip install git+https://github.com/boudinfl/pke.git
# !pip install datasets
# !python -m spacy download en_core_web_sm
# Out:
# Collecting git+https://github.com/alexzvk/pke.git
#   Cloning https://github.com/alexzvk/pke.git to /tmp/pip-req-build-u3xgwjc6
#   Running command git clone --filter=blob:none --quiet https://github.com/alexzvk/pke.git /tmp/pip-req-build-u3xgwjc6
#   Resolved https://github.com/alexzvk/pke.git to commit 1e1459e2eb5618bf793f3ac293ed050bb5e92731
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from pke==2.0.0) (3.8.1)
# Requirement already satisfied: networkx in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from pke==2.0.0) (3.1)
# Requirement already satisfied: numpy in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from pke==2.0.0) (1.24.3)
# Requirement already satisfied: scipy in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from pke==2.0.0) (1.10.1)
# Requirement already satisfied: scikit-learn in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from pke==2.0.0) (1.2.2)
# Requirement already satisfied: unidecode in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from pke==2.0.0) (1.3.6)
# Requirement already satisfied: future in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from pke==2.0.0) (0.18.3)
# Requirement already satisfied: joblib in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from pke==2.0.0) (1.2.0)
# Requirement already satisfied: spacy>=3.2.3 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from pke==2.0.0) (3.5.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (1.0.4)
# Requirement already satisfied: setuptools in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (65.5.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (1.0.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (0.7.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (1.1.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (8.1.10)
# Requirement already satisfied: pathy>=0.10.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (0.10.1)
# Requirement already satisfied: jinja2 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (3.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (2.4.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (4.65.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (1.10.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (6.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (2.0.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (3.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (23.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (2.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (2.31.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy>=3.2.3->pke==2.0.0) (3.0.12)
# Requirement already satisfied: click in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from nltk->pke==2.0.0) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from nltk->pke==2.0.0) (2023.6.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from scikit-learn->pke==2.0.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy>=3.2.3->pke==2.0.0) (4.6.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.3->pke==2.0.0) (2.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.3->pke==2.0.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.3->pke==2.0.0) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.3->pke==2.0.0) (3.1.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.2.3->pke==2.0.0) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.2.3->pke==2.0.0) (0.7.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from jinja2->spacy>=3.2.3->pke==2.0.0) (2.1.3)
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: datasets in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (2.12.0)
# Requirement already satisfied: multiprocess in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from datasets) (0.70.14)
# Requirement already satisfied: xxhash in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from datasets) (3.2.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from datasets) (2023.5.0)
# Requirement already satisfied: numpy>=1.17 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from datasets) (1.24.3)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from datasets) (0.3.6)
# Requirement already satisfied: aiohttp in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from datasets) (3.8.4)
# Requirement already satisfied: requests>=2.19.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from datasets) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from datasets) (6.0)
# Requirement already satisfied: packaging in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from datasets) (23.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from datasets) (0.15.1)
# Requirement already satisfied: pandas in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: responses<0.19 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from datasets) (12.0.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from aiohttp->datasets) (3.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: filelock in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2.0.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 10.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from en-core-web-sm==3.5.0) (3.5.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: jinja2 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.65.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.1)
# Requirement already satisfied: setuptools in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (65.5.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.31.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: pathy>=0.10.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: numpy>=1.15.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.24.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (23.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.10)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.6.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/alexzvk/github-pulled/pke/env/lib/python3.10/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.3)
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
from spacy.tokenizer import _get_regex_pattern

nlp = spacy.load("en_core_web_sm")

# Tokenization fix for in-word hyphens (e.g. 'non-linear' would be kept 
# as one token instead of default spacy behavior of 'non', '-', 'linear')
# https://spacy.io/usage/linguistic-features#native-tokenizer-additions

from spacy.lang.char_classes import ALPHA, ALPHA_LOWER, ALPHA_UPPER
from spacy.lang.char_classes import CONCAT_QUOTES, LIST_ELLIPSES, LIST_ICONS
from spacy.util import compile_infix_regex

# Modify tokenizer infix patterns
infixes = (
    LIST_ELLIPSES
    + LIST_ICONS
    + [
        r"(?<=[0-9])[+\-\*^](?=[0-9-])",
        r"(?<=[{al}{q}])\.(?=[{au}{q}])".format(
            al=ALPHA_LOWER, au=ALPHA_UPPER, q=CONCAT_QUOTES
        ),
        r"(?<=[{a}]),(?=[{a}])".format(a=ALPHA),
        # ✅ Commented out regex that splits on hyphens between letters:
        # r"(?<=[{a}])(?:{h})(?=[{a}])".format(a=ALPHA, h=HYPHENS),
        r"(?<=[{a}0-9])[:<>=/](?=[{a}])".format(a=ALPHA),
    ]
)

infix_re = compile_infix_regex(infixes)
nlp.tokenizer.infix_finditer = infix_re.finditer

# %%
from tqdm import tqdm
from datasets import load_dataset

benchmark = "semeval-2010-pre"
# load the inspec dataset
dataset = load_dataset('taln-ls2n/'+benchmark)

# pre-process training and test splits
train = []
for sample in tqdm(dataset['train']):
    train.append(nlp(sample["title"]+". "+sample["abstract"]))
test = []
for sample in tqdm(dataset['test']):
    test.append(nlp(sample["title"]+". "+sample["abstract"]))
# Out:
# WARNING:datasets.builder:No config specified, defaulting to: semeval-2010-pre/raw
# WARNING:datasets.builder:Found cached dataset semeval-2010-pre (/home/alexzvk/.cache/huggingface/datasets/taln-ls2n___semeval-2010-pre/raw/1.0.0/b40e008b5c96137733e24d9d244d70aa1fe6353ee65e180d8f6948af4027fbe4)
# 100%|██████████| 2/2 [00:00<00:00, 492.06it/s]
# 100%|██████████| 144/144 [00:04<00:00, 30.21it/s]
# 100%|██████████| 100/100 [00:03<00:00, 29.72it/s]

# %%
from pke import compute_document_frequency, compute_lda_model
from string import punctuation


# computing LDA and DF counts

compute_document_frequency(
    documents=train,
    output_file='data/{}.df.gz'.format(benchmark),
    language='en',              # language of the input files
    normalization='stemming',   # use porter stemmer
    stoplist=list(punctuation), # stoplist (punctuation marks)
    n=5                         # compute n-grams up to 5-grams
)

compute_lda_model(
    documents=train,
    output_file="data/{}.lda.pickle.gz".format(benchmark),
    n_topics=500,               # number of topics
    language='en',              # language of the input files
    stoplist=list(punctuation), # stoplist (punctuation marks)
    normalization='stemming'    # use porter stemmer
)

# %%
from pke import load_document_frequency_file, load_lda_model

df = load_document_frequency_file(input_file='data/{}.df.gz'.format(benchmark))
lda_model = load_lda_model(input_file="data/{}.lda.pickle.gz".format(benchmark))

# %%
from pke.unsupervised import *
from timeit import default_timer as timer

outputs = {}
elapsed_times = {}
#for model in [TopicalPageRank]:
for model in [FirstPhrases, TextRank, SingleRank, TopicRank, PositionRank, MultipartiteRank, TfIdf, TopicalPageRank]:
    outputs[model.__name__] = []
    
    extractor = model()
    start = timer()
    for i, doc in enumerate(tqdm(test)):
        extractor.load_document(input=doc, language='en')
        extractor.grammar_selection(grammar="NP: {<ADJ>*<NOUN|PROPN>+}")
        if model.__name__ in ["TfIdf"]:
            extractor.candidate_weighting(df=df)
        elif model.__name__ in ["TopicalPageRank"]:
            extractor.candidate_weighting(lda_model=lda_model)
        else:
            extractor.candidate_weighting()
        outputs[model.__name__].append([u for u,v in extractor.get_n_best(n=10, stemming=True)])
    end = timer()
    elapsed_times[model.__name__] = end - start
    #print("Elapsed time for {}: {:.2f}s - {:.2f} it/s".format(model.__name__, end - start,  len(test) / (end - start)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 7
#       5 elapsed_times = {}
#       6 #for model in [TopicalPageRank]:
# ----> 7 for model in [FirstPhrases, TextRank, SingleRank, TopicRank, PositionRank, MultipartiteRank, TfIdf, TopicalPageRank, RAKE]:
#       8     outputs[model.__name__] = []
#      10     extractor = model()
#
# NameError: name 'RAKE' is not defined

# %%
from nltk.stem.snowball import SnowballStemmer as Stemmer
import numpy as np
    
# populates the references list with stemmed keyphrases
references = []
for sample in tqdm(dataset['test']):
    sample_keyphrases = []
    for keyphrase in sample["keyphrases"]:
        # tokenize keyphrase
        tokens = [token.text for token in nlp(keyphrase)]
        # normalize tokens using Porter's stemming
        stems = [Stemmer('porter').stem(tok.lower()) for tok in tokens]
        sample_keyphrases.append(" ".join(stems))
    references.append(sample_keyphrases)

def evaluate(top_N_keyphrases, references, cutoff=5):
    P = len(set(top_N_keyphrases[:cutoff]) & set(references)) / len(top_N_keyphrases[:cutoff])
    R = len(set(top_N_keyphrases[:cutoff]) & set(references)) / len(references)
    F = (2*P*R)/(P+R) if (P+R) > 0 else 0 
    return (P, R, F)
# Out:
# 100%|██████████| 100/100 [00:09<00:00, 10.90it/s]

# %%
print("## Benchmarking on {}".format(benchmark))
print("| Model | it/s |  F@5 | F@10 |")
print("| :---- | ----:| ---: | ---: |")

# loop through the models
for model in outputs:
    
    f_scores = []
    # compute the P, R, F scores for the model
    for cutoff in [5, 10]:
        scores = []
        for i, output in enumerate(outputs[model]):
            scores.append(evaluate(output, references[i], cutoff))

        # compute the average scores
        P, R, F = np.mean(scores, axis=0)
        f_scores.append(F)
        
    print("| {}  | {:.1f} | {:.2f} | {:.2f} |".format(model,  len(test)/ elapsed_times[model], f_scores[0]*100, f_scores[1]*100))


        # print out the performance of the model
        #print("{} at {} P: {:.3f} R: {:.3f} F: {:.3f}".format(model, cutoff, avg_scores[0], avg_scores[1], avg_scores[2]))
# Out:
# ## Benchmarking on semeval-2010-pre
# | Model | it/s |  F@5 | F@10 |
# | :---- | ----:| ---: | ---: |
# | FirstPhrases  | 200.2 | 13.39 | 14.52 |
# | TextRank  | 120.9 | 8.85 | 12.98 |
# | SingleRank  | 129.4 | 11.27 | 16.36 |
# | TopicRank  | 83.8 | 11.60 | 13.98 |
# | PositionRank  | 126.1 | 12.60 | 16.89 |
# | MultipartiteRank  | 61.4 | 12.83 | 15.36 |
# | TfIdf  | 210.2 | 13.18 | 15.55 |
# | TopicalPageRank  | 19.3 | 11.45 | 16.33 |

# %% [markdown]
# | Model | F@5 | F@10 |
# | :---  | --: | ---: |
# | FirstPhrases  | 0.24 | 0.29 |
# | TextRank  | 0.27 | 0.34 |
# | SingleRank  | 0.27 | 0.34 |
# | TopicRank  | 0.25 | 0.28 |
# | PositionRank  | 0.28 | 0.33 |
# | MultipartiteRank  | 0.25 | 0.29 |
# | TfIdf  | 0.28 | 0.35 |
# | TopicalPageRank  | 0.28 | 0.34 |
